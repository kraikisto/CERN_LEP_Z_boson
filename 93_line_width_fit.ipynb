# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

dataset91 = pd.read_csv('https://raw.githubusercontent.com/kraikisto/CERN_LEP_Z_boson/main/dimuon_short91_f1_000.csv.gz',index_col=False)
dataset92 = pd.read_csv('https://raw.githubusercontent.com/kraikisto/CERN_LEP_Z_boson/main/dimuon_short92_e2_000.csv.gz',index_col=False)
dataset93 = pd.read_csv('https://raw.githubusercontent.com/kraikisto/CERN_LEP_Z_boson/main/dimuon_short93_d2_000.csv.gz',index_col=False)
dataset94 = pd.read_csv('https://raw.githubusercontent.com/kraikisto/CERN_LEP_Z_boson/main/dimuon_short94_c2_000.csv.gz',index_col=False)

print(dataset93.ECM.unique())
# Out:
# [91.372 91.366 91.362 91.364 91.365 91.25  91.114 91.338 91.37  91.36
#  93.078 89.478 91.246 91.254 91.156 91.252 91.26  91.256 91.258 93.08
#  91.248 93.072 89.48  93.066 89.494 89.484 89.49  89.486 89.488 89.482
#  89.487 93.088 93.076 93.081 93.074 93.07 ]

# %%
lum2 = 10
condition2 = np.abs(dataset93.ECM-89.5) < 0.1
dataset93.loc[condition2, "LUM"] = lum2

lum4 = 20
condition4 = np.abs(dataset93.ECM-91.3) < 0.2
dataset93.loc[condition4, "LUM"] = lum4

lum6 = 10
condition6 = np.abs(dataset93.ECM-93) < 0.1
dataset93.loc[condition6, "LUM"] = lum6

# %%
lowerlimit = 89.1
upperlimit = 94
bins=3

fig = plt.figure(figsize=(15, 10))
histogram = plt.hist(dataset93.ECM, bins=bins, range=(lowerlimit,upperlimit), weights = 1/dataset93.LUM)
plt.xlabel('ECM', fontsize=15)
plt.ylabel('Number of events (normalised)', fontsize=15)
plt.title('Number of events of each ECM \n', fontsize=15) 

plt.show()
# Out:
# (array([111.6, 170. , 115.4]), array([89.1       , 90.73333333, 92.36666667, 94.        ]), <BarContainer object of 3 artists>)

# %% [markdown]
# Three datapoints won't let us make a fit (not that it would have given good results anyway)
